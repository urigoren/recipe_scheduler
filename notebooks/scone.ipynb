# %%
import collections, itertools, json, re, operator
from functools import reduce
from pathlib import Path
import pandas as pd

ls = lambda p, g="*.*": print("\n".join(map(str, p.glob(g))))

data_dir = Path("../data/scone")
annot_dir = Path("../annotations/scone")
pd.set_option('display.max_colwidth', 100)
pd.set_option('display.max_rows', 100)

# %%
ls(data_dir)
# Out:
# ../data/scone/scene-test.tsv
# ../data/scone/alchemy-test.tsv
# ../data/scone/alchemy-train.tsv
# ../data/scone/scene-dev.tsv
# ../data/scone/README.md
# ../data/scone/alchemy-train-orig.tsv
# ../data/scone/scene-train-orig.tsv
# ../data/scone/tangrams-test.tsv
# ../data/scone/scene-train.tsv
# ../data/scone/tangrams-train-orig.tsv
# ../data/scone/tangrams-train.tsv
# ../data/scone/alchemy-dev.tsv
# ../data/scone/tangrams-dev.tsv

# %%
parsed = []
with (data_dir / "alchemy-dev.tsv").open('r') as f:
    for line in f:
        idx, *parts = line.strip().split('\t')
        states       = [{int(v.split(':',1)[0]):v.split(':')[1].strip() for v in p.split(' ')} for i,p in enumerate(parts) if i%2==0]
        instructions = [p for i,p in enumerate(parts) if i%2==1]
        instructions.insert(0,"INIT")
        seq = 0
        for state, instruction in zip(states,instructions):
            d = state
            d["instruction"]=instruction
            d['id']=idx
            d['seq']=seq
            parsed.append(d)
            seq+=1
df = pd.DataFrame(parsed)
df.head(100)
# Out:
#       1    2    3    4    5    6    7  \
# 0     _    g    p    o    g    r    y
# 1     _    g    p    _    g    r    y
# 2     _    _    p    _    g    r   yg
# 3     _    _    p    _    g    r   bb
# 4     _    _    p    _    _    r  bbg
# 5     _    _    p    _    _    r  bbb
# 6     y    _    y    y    p    g  ooo
# 7     y    _    y    y    p    _  ooo
# 8     y    _    y    y    _    _  ooo
# 9     y    _    _   yy    _    _  ooo
# 10    y    _    _    y    _    _  ooo
# 11    y    _    _    _    _    _  ooo
# 12    o    g    g   rr    r    r    y
# 13    o    g    g    r    r    r    y
# 14    o    _    g   rg    r    r    y
# 15    o    _    g   bb    r    r    y
# 16    o    _    g   bb    _    r    y
# 17    _    _    g   bb    _    r    y
# 18    y  ggg    y    o    _    p    _
# 19    y    g    y    o    _    p    _
# 20    y   go    y    _    _    p    _
# 21    y   bb    y    _    _    p    _
# 22    y    b    y    _    _    p    _
# 23    y    _    y    _    _    p    _
# 24    p    p    o    g    r    y    o
# 25    p    p    o    _    r    y    o
# 26    _    p    o    _    r   yp    o
# 27    _    p    o    _    r   bb    o
# 28    _    p    _    _    r   bb   oo
# 29    _    p    _    _    r    _   oo
# 30    _    g    o    r    r    p    g
# 31    _    g    o    _    r    p    g
# 32    _    g   og    _    r    p    _
# 33    _   gr   og    _    _    p    _
# 34    _   bb   og    _    _    p    _
# 35    _    _   og    _    _  pbb    _
# 36    o    o    r    p    _   gg    g
# 37    o    o    r    _    _   gg    g
# 38    o   og    r    _    _   gg    _
# 39    o   bb    r    _    _   gg    _
# 40    o    _    r    _    _   gg    _
# 41  ogg    _    r    _    _    _    _
# 42    g    _    g   gg    r    y    o
# 43    g    _    g   gg    _    y    o
# 44    g    _    g   gg    _    _   oy
# 45    g    _    g   gg    _    _   bb
# 46    g    _    _   gg    _    _  bbg
# 47    g    _    _   gg    _    _    _
# 48    p    g    p    p    o    g    g
# 49    p    g    p    p    o    _    g
# 50   pg    _    p    p    o    _    g
# 51  pgo    _    p    p    _    _    g
# 52  bbb    _    p    p    _    _    g
# 53   bb    _    p    p    _    _    g
# 54    y    g    y    o    p    p    o
# 55    y    g    _    o    p    p    o
# 56    _    g    _    o   py    p    o
# 57    _    g    _    o  pyo    p    _
# 58    _    g    _    o  bbb    p    _
# 59    _    _    _    o  bbb    p    _
# 60    y    y  rrr    _    _   pp    r
# 61    y    y    _    _    _   pp    r
# 62   yy    _    _    _    _   pp    r
# 63  yyr    _    _    _    _   pp    _
# 64  bbb    _    _    _    _   pp    _
# 65  bbb    _    _    _    _    p    _
# 66    o    o    p    _   pp    y    y
# 67    _    o    p    _   pp    y    y
# 68    _    o   py    _   pp    _    y
# 69    _    o   bb    _   pp    _    y
# 70    _    o  bby    _   pp    _    _
# 71    _    o  bbb    _   pp    _    _
# 72    y    _   oo    y    o    g    o
# 73    y    _   oo    y    o    g    _
# 74    y    _  oog    y    o    _    _
# 75    y    _  bbb    y    o    _    _
# 76    y    _    b    y    o    _    _
# 77    _    _   by    y    o    _    _
# 78    y    p    o    y    y    g    r
# 79    y    p    o    y    _    g    r
# 80   yg    p    o    y    _    _    r
# 81    _    p    o  ygy    _    _    r
# 82    _    p    o  bbb    _    _    r
# 83    _    p    o    b    _    _    r
# 84   gg    g   oo    g   rr    o    o
# 85    g    g   oo    g   rr    o    o
# 86  grr    g   oo    g    _    o    o
# 87  grr    g   oo    g    _    o    _
# 88    g    g   oo    g    _    o    _
# 89  goo    g    _    g    _    o    _
# 90    p    o    o    g    r    _    g
# 91    p    o    o    g    r    _    _
# 92   pg    o    o    _    r    _    _
# 93   bb    o    o    _    r    _    _
# 94  bbo    o    _    _    r    _    _
# 95  bbb    o    _    _    r    _    _
# 96    _    g    r    _    p    p    r
# 97    _    g    r    _    p    p    _
# 98    _    g   rp    _    _    p    _
# 99    _    g   bb    _    _    p    _
#
#                                                                           instruction  \
# 0                                                                                INIT
# 1                                                       throw out the orange chemical
# 2              then, add the leftmost beaker of green chemical to the yellow chemical
# 3                                                                              mix it
# 4                                        then, add the remaining green chemical to it
# 5                                                                        mix that too
# 6                                                                                INIT
# 7                                                              throw out green beaker
# 8                                                                throw out purple one
# 9                                                   pour third beaker into fourth one
# 10                                                   throw out one unit of fourth one
# 11                                                            throw out fourth beaker
# 12                                                                               INIT
# 13                              drain 1 unit from the leftmost beaker of red chemical
# 14                          then, add the green chemical from the second beaker to it
# 15                                                                             mix it
# 16                                   next, empty out the first beaker of red chemical
# 17                                                       same for the orange chemical
# 18                                                                               INIT
# 19                                            empty out 2 units of the green chemical
# 20                                                      add the orange chemical to it
# 21                                                                             mix it
# 22                                                       then, throw out 1 unit of it
# 23                                      finally, dump out that remaining unit as well
# 24                                                                               INIT
# 25                                        throw out the contents of the fourth beaker
# 26                                        pour the first beaker into the sixth beaker
# 27                                                               mix the sixth beaker
# 28                                         throw out the contents of the third beaker
# 29                                         throw out the contents of the sixth beaker
# 30                                                                               INIT
# 31                                                            throw out fourth beaker
# 32                                                   pour last beaker into orange one
# 33                                                    pour red beaker into second one
# 34                                                          second beaker turns brown
# 35                                                  pour brown beaker into purple one
# 36                                                                               INIT
# 37                                                            throw out purple beaker
# 38                                                   pour last beaker into second one
# 39                                                                     it turns brown
# 40                                                             throw out brown beaker
# 41                                                  pour green beaker into orange one
# 42                                                                               INIT
# 43                                                               throw out red beaker
# 44                                                 pour yellow beaker into orange one
# 45                                                                     it turns brown
# 46                                                   pour third beaker into brown one
# 47                                                              throw out last beaker
# 48                                                                               INIT
# 49                                                             throw out sixth beaker
# 50                                                  pour second beaker into first one
# 51                                                  pour orange beaker into first one
# 52                                                                     it turns brown
# 53                                                        throw out one unit of brown
# 54                                                                               INIT
# 55                                  throw out the rightmost beaker of yellow chemical
# 56  then, add the remaining yellow chemical to the leftmost beaker of purple chemical
# 57                               add the last beaker of orange chemical to it as well
# 58                                                                             mix it
# 59                                              finally, throw out the green chemical
# 60                                                                               INIT
# 61                                                         empty out the third beaker
# 62                  then, add the yellow chemical from the second beaker to the first
# 63                                                 add the red chemical to it as well
# 64                                                                             mix it
# 65                                              then, drain 1 unit of purple chemical
# 66                                                                               INIT
# 67                                                             throw out first beaker
# 68                                                   pour sixth beaker into third one
# 69                                                                     it turns brown
# 70                                                  pour yellow beaker into brown one
# 71                                                          it turns completely brown
# 72                                                                               INIT
# 73                                                              throw out last beaker
# 74                                                   pour green beaker into third one
# 75                                                                     it turns brown
# 76                                                   throw out two units of brown one
# 77                                                   pour first beaker into brown one
# 78                                                                               INIT
# 79                                                             throw out fifth beaker
# 80                                                   pour green beaker into first one
# 81     pour first beaker into fourth one, with green going in first and yellow on top
# 82                                                                     it turns brown
# 83                                                throw out two units of brown beaker
# 84                                                                               INIT
# 85                                                 throw out one unit of first beaker
# 86                                                     pour red beaker into first one
# 87                                                              throw out last beaker
# 88                                                throw out red units of first beaker
# 89                                                   pour third beaker into first one
# 90                                                                               INIT
# 91                                                          empty out the last beaker
# 92                      then, add the remaining green chemical to the purple chemical
# 93                                                                             mix it
# 94                          next, add the orange chemical from the third beaker to it
# 95                                                                       mix it again
# 96                                                                               INIT
# 97                                                          empty out the last beaker
# 98               then, add the leftmost purple chemical to the beaker of red chemical
# 99                                                                             mix it
#
#           id  seq
# 0   dev-1830    0
# 1   dev-1830    1
# 2   dev-1830    2
# 3   dev-1830    3
# 4   dev-1830    4
# 5   dev-1830    5
# 6   dev-1831    0
# 7   dev-1831    1
# 8   dev-1831    2
# 9   dev-1831    3
# 10  dev-1831    4
# 11  dev-1831    5
# 12  dev-1834    0
# 13  dev-1834    1
# 14  dev-1834    2
# 15  dev-1834    3
# 16  dev-1834    4
# 17  dev-1834    5
# 18  dev-1835    0
# 19  dev-1835    1
# 20  dev-1835    2
# 21  dev-1835    3
# 22  dev-1835    4
# 23  dev-1835    5
# 24  dev-1836    0
# 25  dev-1836    1
# 26  dev-1836    2
# 27  dev-1836    3
# 28  dev-1836    4
# 29  dev-1836    5
# 30  dev-1837    0
# 31  dev-1837    1
# 32  dev-1837    2
# 33  dev-1837    3
# 34  dev-1837    4
# 35  dev-1837    5
# 36  dev-1838    0
# 37  dev-1838    1
# 38  dev-1838    2
# 39  dev-1838    3
# 40  dev-1838    4
# 41  dev-1838    5
# 42  dev-1840    0
# 43  dev-1840    1
# 44  dev-1840    2
# 45  dev-1840    3
# 46  dev-1840    4
# 47  dev-1840    5
# 48  dev-1841    0
# 49  dev-1841    1
# 50  dev-1841    2
# 51  dev-1841    3
# 52  dev-1841    4
# 53  dev-1841    5
# 54  dev-1842    0
# 55  dev-1842    1
# 56  dev-1842    2
# 57  dev-1842    3
# 58  dev-1842    4
# 59  dev-1842    5
# 60  dev-1843    0
# 61  dev-1843    1
# 62  dev-1843    2
# 63  dev-1843    3
# 64  dev-1843    4
# 65  dev-1843    5
# 66  dev-1844    0
# 67  dev-1844    1
# 68  dev-1844    2
# 69  dev-1844    3
# 70  dev-1844    4
# 71  dev-1844    5
# 72  dev-1845    0
# 73  dev-1845    1
# 74  dev-1845    2
# 75  dev-1845    3
# 76  dev-1845    4
# 77  dev-1845    5
# 78  dev-1846    0
# 79  dev-1846    1
# 80  dev-1846    2
# 81  dev-1846    3
# 82  dev-1846    4
# 83  dev-1846    5
# 84  dev-1847    0
# 85  dev-1847    1
# 86  dev-1847    2
# 87  dev-1847    3
# 88  dev-1847    4
# 89  dev-1847    5
# 90  dev-1848    0
# 91  dev-1848    1
# 92  dev-1848    2
# 93  dev-1848    3
# 94  dev-1848    4
# 95  dev-1848    5
# 96  dev-1849    0
# 97  dev-1849    1
# 98  dev-1849    2
# 99  dev-1849    3

# %%
lst = ['a','b']
lst.insert(0,'c')
lst
# Out:
# ['c', 'a', 'b']

# %%
beakers = reduce(operator.or_, [set(df[i].unique()) for i in range(1,8)], set())
colors = list({c for b in beakers for c in b if '_' not in c})

# %%
len(beakers)
# Out:
# 114

# %%
colors
# Out:
# ['b', 'p', 'g', 'r', 'o', 'y']

# %%
desc = {"p": "Purple", "o": "Orange", "y": "Yellow", "b": "Brown", "g": "Green", "r":"Red"}

# %%
ingredients = {"I" + (c).upper() : desc[c] for c in colors}
tools = {"T" + (c + c).upper() : desc[c] for c in colors}
time_lengths = {"L" + (c + c + c).upper() : desc[c] for c in colors}
ingredients
# Out:
# {'IB': 'Brown',
#  'IP': 'Purple',
#  'IG': 'Green',
#  'IR': 'Red',
#  'IO': 'Orange',
#  'IY': 'Yellow'}

# %%
tools
# Out:
# {'TBB': 'Brown',
#  'TPP': 'Purple',
#  'TGG': 'Green',
#  'TRR': 'Red',
#  'TOO': 'Orange',
#  'TYY': 'Yellow'}

# %%
time_lengths
# Out:
# {'LBBB': 'Brown',
#  'LPPP': 'Purple',
#  'LGGG': 'Green',
#  'LRRR': 'Red',
#  'LOOO': 'Orange',
#  'LYYY': 'Yellow'}

# %%
def init_instruction(d):
    ret = ""
    for i in range(1,8):
        if d[i]=='_':
            continue
        if len(d[i])==1:
            u = "1 unit"
        elif len(d[i])==2:
            u = "2 units"
        elif len(d[i])==3:
            u = "3 units"
        else:
            u = "ERROR"
        ret += "Put " + u+ " of " + desc[d[i][0]] + " color in beaker #" + str(i) + ", "
    return ret

# %%
df.loc[df["instruction"]=="INIT", "instruction"]=df[df["instruction"]=="INIT"].apply(init_instruction,axis=1)
df
# Out:
#       1  2   3    4  5  6    7  \
# 0     _  g   p    o  g  r    y
# 1     _  g   p    _  g  r    y
# 2     _  _   p    _  g  r   yg
# 3     _  _   p    _  g  r   bb
# 4     _  _   p    _  _  r  bbg
# ...  .. ..  ..  ... .. ..  ...
# 1465  r  _  gg    o  g  r    y
# 1466  r  _  gg   oy  g  r    _
# 1467  _  _  gg  oyr  g  r    _
# 1468  _  _  gg  bbb  g  r    _
# 1469  _  _  gg    _  g  r    _
#
#                                                                                               instruction  \
# 0     Put 1 unit of Green color in beaker 2, Put 1 unit of Purple color in beaker 3, Put 1 unit of Ora...
# 1                                                                           throw out the orange chemical
# 2                                  then, add the leftmost beaker of green chemical to the yellow chemical
# 3                                                                                                  mix it
# 4                                                            then, add the remaining green chemical to it
# ...                                                                                                   ...
# 1465                                                                              throw out second beaker
# 1466                                                                   pour yellow beaker into orange one
# 1467                                                                    pour first beaker into fourth one
# 1468                                                                            it turns completely brown
# 1469                                                                                  throw out brown one
#
#             id  seq
# 0     dev-1830    0
# 1     dev-1830    1
# 2     dev-1830    2
# 3     dev-1830    3
# 4     dev-1830    4
# ...        ...  ...
# 1465  dev-2128    1
# 1466  dev-2128    2
# 1467  dev-2128    3
# 1468  dev-2128    4
# 1469  dev-2128    5
#
# [1470 rows x 10 columns]

# %%
def serialize(grp):
    grp=grp.sort_values(by="seq")
    ret = {"instructions": [], "ingredients":list(ingredients.values()), "normalized_ingredients": ingredients, "title": grp.head(1)["id"].values[0], "status": 0, "validations": [], "photo_url": "", "url": "", "labels": []}
    for idx,row in grp.iterrows():
        ret["instructions"].append(str(row["instruction"]))
        ret["labels"].append([])
    return ret
ds_annotations = df.groupby("id").apply(serialize)
ds_annotations
# Out:
# id
# dev-1830    {'instructions': ['Put 1 unit of Green color in beaker 2, Put 1 unit of Purple color in beaker 3...
# dev-1831    {'instructions': ['Put 1 unit of Yellow color in beaker 1, Put 1 unit of Yellow color in beaker ...
# dev-1834    {'instructions': ['Put 1 unit of Orange color in beaker 1, Put 1 unit of Green color in beaker 2...
# dev-1835    {'instructions': ['Put 1 unit of Yellow color in beaker 1, Put 3 units of Green color in beaker ...
# dev-1836    {'instructions': ['Put 1 unit of Purple color in beaker 1, Put 1 unit of Purple color in beaker ...
#                                                            ...
# dev-2123    {'instructions': ['Put 1 unit of Red color in beaker 1, Put 1 unit of Orange color in beaker 2, ...
# dev-2124    {'instructions': ['Put 1 unit of Yellow color in beaker 1, Put 1 unit of Orange color in beaker ...
# dev-2125    {'instructions': ['Put 1 unit of Red color in beaker 2, Put 1 unit of Yellow color in beaker 3, ...
# dev-2126    {'instructions': ['Put 1 unit of Green color in beaker 1, Put 1 unit of Purple color in beaker 2...
# dev-2128    {'instructions': ['Put 1 unit of Red color in beaker 1, Put 1 unit of Green color in beaker 2, P...
# Length: 245, dtype: object

# %%
for idx,v in ds_annotations.iteritems():
    idx=idx.split('-',1)[1]
    with (annot_dir/f"{idx}.json").open('w') as f:
        try:
            json.dump(v,f,indent=4)
        except TypeError:
            print({k:type(w) for k,w in v.items()})

# %%
df[df["id"]=="dev-2035"]
# Out:
#       1  2    3  4  5    6  7  \
# 1002  r  o  ooo  o  o  rrr  o
# 1003  r  o  ooo  o  o    r  o
# 1004  r  o  ooo  _  o   ro  o
# 1005  r  o    o  _  o   ro  o
# 1006  r  o    o  _  o   bb  o
# 1007  _  o    o  _  o  bbr  o
#
#                                                                                               instruction  \
# 1002  Put 1 unit of Red color in beaker 1, Put 1 unit of Orange color in beaker 2, Put 3 units of Oran...
# 1003                                                  drain 2 units from the right beaker of red chemical
# 1004                                           then, add the orange chemical from the fourth beaker to it
# 1005                                                                  drain 2 units from the third beaker
# 1006                                                                  next, mix the second to last beaker
# 1007                                                                 add the remaining red chemical to it
#
#             id  seq
# 1002  dev-2035    0
# 1003  dev-2035    1
# 1004  dev-2035    2
# 1005  dev-2035    3
# 1006  dev-2035    4
# 1007  dev-2035    5
